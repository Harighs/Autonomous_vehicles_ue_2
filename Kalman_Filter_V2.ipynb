# %%
# Install the protobuf compiler
# !apt install protobuf-compiler

# Compile the proto file to generate Python classes
# !protoc --python_out=. frame.proto
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# protobuf-compiler is already the newest version (3.12.4-1ubuntu7.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Could not make proto path relative: frame.proto: No such file or directory

# %%
import os
import sys
import numpy as np

# Assuming you've added the directory containing the generated Python module to the Python path
sys.path.append('/content/sample_data/data')

from frame_pb2 import Frame

def parse_file(pb_path):
    frame_data = Frame()
    data = None
    try:
        with open(pb_path, 'rb') as file:
            data = file.read()
            print("Data Length:", len(data))  # Debugging statement
        frame_data.ParseFromString(data)
    except Exception as e:
        print(f"Failed to parse {pb_path}: {str(e)}")
        return None, None, None

    if frame_data.lidars and frame_data.lidars[0].detections:
        first_detection = frame_data.lidars[0].detections[0]
        x = first_detection.pos[0] if len(first_detection.pos) > 0 else None
        y = first_detection.pos[1] if len(first_detection.pos) > 1 else None
        z = first_detection.pos[2] if len(first_detection.pos) > 2 else None
        return x, y, z
    return None, None, None

def parse_pb_files(directory_path):
    file_paths = [os.path.join(directory_path, f) for f in os.listdir(directory_path) if f.endswith('.pb')]
    print("Processing files:", file_paths)  # Debugging statement
    positions = []
    for path in file_paths:
        pos = parse_file(path)
        if pos and pos[0] is not None:
            positions.append(pos)
    return np.array(positions)

def kalman_filter(z, dt):
    if z.size == 0:
        raise ValueError("No measurements available to process.")
    x = np.array([[z[0][0]], [z[0][1]], [0], [0]])
    P = np.eye(4)
    F = np.array([[1, 0, dt, 0], [0, 1, 0, dt], [0, 0, 1, 0], [0, 0, 0, 1]])
    H = np.array([[1, 0, 0, 0], [0, 1, 0, 0]])
    R = np.array([[0.1, 0], [0, 0.1]])
    Q = np.eye(4) * 0.01

    for i in range(1, len(z)):
        x = F @ x
        P = F @ P @ F.T + Q
        S = H @ P @ H.T + R
        K = P @ H.T @ np.linalg.inv(S)
        y = z[i] - (H @ x)
        x = x + (K @ y)
        P = (np.eye(4) - (K @ H)) @ P
    return x, P

directory_path = '/content/sample_data/data'  # Adjust as needed
measurements = parse_pb_files(directory_path)
dt = 1.0  # Time step between measurements

if measurements.size > 0:
    final_state, final_covariance = kalman_filter(measurements, dt)
    print("Final State:", final_state)
    print("Final Covariance Matrix:\n", final_covariance)
else:
    print("No data to process.")
# Out:
# Processing files: ['/content/sample_data/data/frame_109.pb', '/content/sample_data/data/frame_158.pb', '/content/sample_data/data/frame_50.pb', '/content/sample_data/data/frame_148.pb', '/content/sample_data/data/frame_142.pb', '/content/sample_data/data/frame_47.pb', '/content/sample_data/data/frame_180.pb', '/content/sample_data/data/frame_186.pb', '/content/sample_data/data/frame_159.pb', '/content/sample_data/data/frame_64.pb', '/content/sample_data/data/frame_62.pb', '/content/sample_data/data/frame_197.pb', '/content/sample_data/data/frame_3.pb', '/content/sample_data/data/frame_22.pb', '/content/sample_data/data/frame_8.pb', '/content/sample_data/data/frame_18.pb', '/content/sample_data/data/frame_114.pb', '/content/sample_data/data/frame_66.pb', '/content/sample_data/data/frame_160.pb', '/content/sample_data/data/frame_135.pb', '/content/sample_data/data/frame_137.pb', '/content/sample_data/data/frame_103.pb', '/content/sample_data/data/frame_28.pb', '/content/sample_data/data/frame_157.pb', '/content/sample_data/data/frame_153.pb', '/content/sample_data/data/frame_155.pb', '/content/sample_data/data/frame_82.pb', '/content/sample_data/data/frame_183.pb', '/content/sample_data/data/frame_136.pb', '/content/sample_data/data/frame_80.pb', '/content/sample_data/data/frame_9.pb', '/content/sample_data/data/frame_59.pb', '/content/sample_data/data/frame_131.pb', '/content/sample_data/data/frame_123.pb', '/content/sample_data/data/frame_72.pb', '/content/sample_data/data/frame_88.pb', '/content/sample_data/data/frame_61.pb', '/content/sample_data/data/frame_127.pb', '/content/sample_data/data/frame_106.pb', '/content/sample_data/data/frame_165.pb', '/content/sample_data/data/frame_23.pb', '/content/sample_data/data/frame_164.pb', '/content/sample_data/data/frame_16.pb', '/content/sample_data/data/frame_14.pb', '/content/sample_data/data/frame_149.pb', '/content/sample_data/data/frame_68.pb', '/content/sample_data/data/frame_116.pb', '/content/sample_data/data/frame_192.pb', '/content/sample_data/data/frame_196.pb', '/content/sample_data/data/frame_85.pb', '/content/sample_data/data/frame_140.pb', '/content/sample_data/data/frame_24.pb', '/content/sample_data/data/frame_11.pb', '/content/sample_data/data/frame_118.pb', '/content/sample_data/data/frame_73.pb', '/content/sample_data/data/frame_54.pb', '/content/sample_data/data/frame_25.pb', '/content/sample_data/data/frame_40.pb', '/content/sample_data/data/frame_194.pb', '/content/sample_data/data/frame_43.pb', '/content/sample_data/data/frame_191.pb', '/content/sample_data/data/frame_27.pb', '/content/sample_data/data/frame_13.pb', '/content/sample_data/data/frame_112.pb', '/content/sample_data/data/frame_152.pb', '/content/sample_data/data/frame_122.pb', '/content/sample_data/data/frame_45.pb', '/content/sample_data/data/frame_181.pb', '/content/sample_data/data/frame_34.pb', '/content/sample_data/data/frame_120.pb', '/content/sample_data/data/frame_93.pb', '/content/sample_data/data/frame_147.pb', '/content/sample_data/data/frame_31.pb', '/content/sample_data/data/frame_65.pb', '/content/sample_data/data/frame_79.pb', '/content/sample_data/data/frame_17.pb', '/content/sample_data/data/frame_150.pb', '/content/sample_data/data/frame_171.pb', '/content/sample_data/data/frame_188.pb', '/content/sample_data/data/frame_124.pb', '/content/sample_data/data/frame_89.pb', '/content/sample_data/data/frame_90.pb', '/content/sample_data/data/frame_176.pb', '/content/sample_data/data/frame_53.pb', '/content/sample_data/data/frame_168.pb', '/content/sample_data/data/frame_67.pb', '/content/sample_data/data/frame_38.pb', '/content/sample_data/data/frame_49.pb', '/content/sample_data/data/frame_1.pb', '/content/sample_data/data/frame_144.pb', '/content/sample_data/data/frame_108.pb', '/content/sample_data/data/frame_48.pb', '/content/sample_data/data/frame_110.pb', '/content/sample_data/data/frame_190.pb', '/content/sample_data/data/frame_126.pb', '/content/sample_data/data/frame_83.pb',  ...
# Data Length: 10520202
# Data Length: 10520320
# Data Length: 10519843
# Data Length: 10520124
# Data Length: 10520240
# Data Length: 10519843
# Data Length: 10520832
# Data Length: 10521116
# Data Length: 10520318
# Data Length: 10519785
# Data Length: 10519787
# Data Length: 10521406
# Data Length: 10519852
# Data Length: 10519727
# Data Length: 10519852
# Data Length: 10519797
# Data Length: 10520018
# Data Length: 10519785
# Data Length: 10520320
# Data Length: 10520182
# Data Length: 10520300
# Data Length: 10520164
# Data Length: 10519727
# Data Length: 10520318
# Data Length: 10520310
# Data Length: 10520308
# Data Length: 10519845
# Data Length: 10520832
# Data Length: 10520242
# Data Length: 10519843
# Data Length: 10519852
# Data Length: 10519785
# Data Length: 10520010
# Data Length: 9437184
# Failed to parse /content/sample_data/data/frame_123.pb: Error parsing message with type 'Frame'
# Data Length: 10519787
# Data Length: 10519969
# Data Length: 10519787
# Data Length: 10520010
# Data Length: 10520156
# Data Length: 10520756
# Data Length: 10519729
# Data Length: 10520628
# Data Length: 10519797
# Data Length: 10519795
# Data Length: 10520126
# Data Length: 10519785
# Data Length: 10519902
# Data Length: 10521544
# Data Length: 10521408
# Data Length: 10519967
# Data Length: 10520356
# Data Length: 10519729
# Data Length: 10519851
# Data Length: 10519902
# Data Length: 10519787
# Data Length: 10519785
# Data Length: 10519725
# Data Length: 10519843
# Data Length: 10521474
# Data Length: 10519843
# Data Length: 10521540
# Data Length: 10519725
# Data Length: 10519797
# Data Length: 10520134
# Data Length: 10520308
# Data Length: 10520018
# Data Length: 10519843
# Data Length: 10520832
# Data Length: 10519785
# Data Length: 10519902
# Data Length: 10520037
# Data Length: 10520182
# Data Length: 10519727
# Data Length: 10519785
# Data Length: 10519845
# Data Length: 10519795
# Data Length: 10520252
# Data Length: 10520892
# Data Length: 10521520
# Data Length: 10520010
# Data Length: 10519969
# Data Length: 10519971
# Data Length: 10520890
# Data Length: 7340032
# Failed to parse /content/sample_data/data/frame_53.pb: Error parsing message with type 'Frame'
# Data Length: 10520822
# Data Length: 10519785
# Data Length: 10519845
# Data Length: 10519843
# Data Length: 10519850
# Data Length: 10520240
# Data Length: 10520154
# Data Length: 10519843
# Data Length: 10520132
# Data Length: 10521544
# Data Length: 10520066
# Data Length: 10519843
# Data Length: 10519787
# Data Length: 10520822
# Data Length: 10520832
# Data Length: 10520008
# Data Length: 10520107
# Data Length: 10520358
# Data Length: 10520105
# Data Length: 10519843
# Data Length: 10519785
# Data Length: 10520880
# Data Length: 10519900
# Data Length: 10520356
# Data Length: 10520068
# Data Length: 10520222
# Data Length: 10519969
# Data Length: 10519727
# Data Length: 10519843
# Data Length: 10519852
# Data Length: 10521474
# Data Length: 10520066
# Data Length: 10520300
# Data Length: 10520068
# Data Length: 10519854
# Data Length: 10519785
# Data Length: 10519843
# Data Length: 10519729
# Data Length: 10519902
# Data Length: 10520163
# Data Length: 10519843
# Data Length: 10520166
# Data Length: 10520101
# Data Length: 10520502
# Data Length: 10520310
# Data Length: 10520910
# Data Length: 10520310
# Data Length: 10519795
# Data Length: 10519729
# Data Length: 10519785
# Data Length: 10519785
# Data Length: 10520008
# Data Length: 10519785
# Data Length: 10520182
# Data Length: 10519962
# Data Length: 10520154
# Data Length: 10519786
# Data Length: 10520037
# Data Length: 10521202
# Data Length: 10521182
# Data Length: 10520136
# Data Length: 9437184
# Failed to parse /content/sample_data/data/frame_52.pb: Error parsing message with type 'Frame'
# Data Length: 10519854
# Data Length: 10520890
# Data Length: 10520892
# Data Length: 10519843
# Data Length: 10519795
# Data Length: 10519971
# Data Length: 10519845
# Data Length: 10520892
# Data Length: 10520164
# Data Length: 10519843
# Data Length: 10519785
# Data Length: 10520888
# Data Length: 10521046
# Data Length: 10520008
# Data Length: 10520832
# Data Length: 10519727
# Data Length: 10520182
# Data Length: 10521658
# Data Length: 10519787
# Data Length: 10519785
# Data Length: 10519785
# Data Length: 10519727
# Data Length: 10520008
# Data Length: 10520252
# Data Length: 10519785
# Data Length: 10520834
# Data Length: 10519853
# Data Length: 10519729
# Data Length: 10519904
# Data Length: 10519843
# Data Length: 10519785
# Data Length: 10520105
# Data Length: 10520444
# Data Length: 9437184
# Failed to parse /content/sample_data/data/frame_55.pb: Error parsing message with type 'Frame'
# Data Length: 10520754
# Data Length: 10520630
# Data Length: 10520164
# Data Length: 10519845
# Data Length: 10519843
# Data Length: 10519843
# Data Length: 10520037
# Data Length: 10520832
# Data Length: 10519848
# Data Length: 10520156
# Data Length: 10519785
# Data Length: 10520018
# Data Length: 10520037
# Data Length: 10519841
# Data Length: 10520356
# Data Length: 10520892
# Data Length: 10519852
# Data Length: 10519901
# Data Length: 10521542
# Final State: [[ -2.65541858 -22.5519993    2.22889007]
#  [ -2.65541858 -22.5519993    2.22889007]
#  [ -3.6611314   -9.24319428   0.52531278]
#  [ -3.6611314   -9.24319428   0.52531278]]
# Final Covariance Matrix:
#  [[0.05781285 0.         0.02053951 0.        ]
#  [0.         0.05781285 0.         0.02053951]
#  [0.02053951 0.         0.02814714 0.        ]
#  [0.         0.02053951 0.         0.02814714]]
